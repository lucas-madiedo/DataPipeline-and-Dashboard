# %%
import pandas as pd

# %%
path='../data/processed/01_FULL_raw_table.csv'
raw_df = pd.read_csv(path)
#NoJOB = TRUE . muestra todos
#NoJOb = FALSE -> NO muestra nojobs

def make_final_base_table(raw_df, country,nojob):
    # creamos un nuevo df con las columnas necesarias más una
    df = raw_df[['country', 'title', 'age', 'gender']]

    df = df.rename(columns={'country': 'Country',
                            'title': 'Job Title',
                            'age': 'Age',
                            'gender': 'Quantity'
                            })
    
    # se añade una columna sobre gender con la cuenta de pais, job, tabajo
    df = df.groupby(['Country', 'Job Title', 'Age']).agg('count').reset_index()
    df = df[df['Quantity'].notna()]
    
    
    if nojob == False:
        filter_no_current_job = df['Job Title'] != 'No Full-Time Job'
        df=df[filter_no_current_job]
        

    # Si no se mete valor, devuelve el df tal cual.
    if country == 'all':
        df['Percentage'] = df['Quantity'] / df['Quantity'].sum() * 100
        df = df.sort_values(by=['Percentage'], ascending=False)
        return df

    # Si se mete valor, hace un filtro y recalcula el porcentaje.
    else:
        filter_country = df['Country'] == country
        df = df[filter_country]
        df['Percentage'] = df['Quantity'] / df['Quantity'].sum() * 100
        df = df.sort_values(by=['Percentage'], ascending=False)
        return df

    
    print(df['Country'].count())

    
def pretty_df_percentage(df):
    df['Percentage'] = df['Percentage'].round(2).apply(lambda x : str(x)+'%')
    return df

def main_table_ch1 (raw_df,pais='all',nojob=True):
    table = make_final_base_table(raw_df,pais,nojob)
    final_table = pretty_df_percentage(table)

    FILES_BASE_PATH = '../data/results/'
    name = FILES_BASE_PATH + 'challenge1.csv'
    final_table.to_csv(name, index=False)

    return final_table

# %%
df =main_table_ch1(raw_df)

# %%
df
# Out:
#              Country                                          Job Title  Age  \
# 6101  United Kingdom                                   No Full-Time Job   43
# 2218         Germany                                   No Full-Time Job   19
# 2216         Germany                                   No Full-Time Job   17
# 2217         Germany                                   No Full-Time Job   18
# 1464          France                                   No Full-Time Job   40
# 1444          France                                   No Full-Time Job   20
# 2215         Germany                                   No Full-Time Job   16
# 5322           Spain                                   No Full-Time Job   41
# 6073  United Kingdom                                   No Full-Time Job   15
# 2214         Germany                                   No Full-Time Job   15
# 2219         Germany                                   No Full-Time Job   20
# 1442          France                                   No Full-Time Job   18
# 5300           Spain                                   No Full-Time Job   19
# 2224         Germany                                   No Full-Time Job   25
# 3307           Italy                                   No Full-Time Job   25
# 3313           Italy                                   No Full-Time Job   31
# 3323           Italy                                   No Full-Time Job   41
# 2239         Germany                                   No Full-Time Job   40
# 1443          France                                   No Full-Time Job   19
# 6074  United Kingdom                                   No Full-Time Job   16
# 6077  United Kingdom                                   No Full-Time Job   19
# 6076  United Kingdom                                   No Full-Time Job   18
# 6098  United Kingdom                                   No Full-Time Job   40
# 6099  United Kingdom                                   No Full-Time Job   41
# 4157          Poland                                   No Full-Time Job   19
# 4156          Poland                                   No Full-Time Job   18
# 5321           Spain                                   No Full-Time Job   40
# 3304           Italy                                   No Full-Time Job   22
# 6075  United Kingdom                                   No Full-Time Job   17
# 1449          France                                   No Full-Time Job   25
# ...              ...                                                ...  ...
# 2150         Germany  Geographic Information Systems Data Manager (G...   59
# 2149         Germany  Geographic Information Systems Data Manager (G...   50
# 2146         Germany  Geographic Information Systems Data Manager (G...   37
# 2145         Germany  Geographic Information Systems Data Manager (G...   30
# 2144         Germany  Geographic Information Systems Data Manager (G...   29
# 2143         Germany  Geographic Information Systems Data Administra...   61
# 2142         Germany  Geographic Information Systems Data Administra...   55
# 2163         Germany  Geographic Information Systems Data Specialist...   49
# 2165         Germany  Geographic Information Systems Data Specialist...   54
# 2191         Germany                       Internet Database Specialist   41
# 2181         Germany    Head of Information Systems and Data Processing   46
# 2190         Germany                       Internet Database Specialist   40
# 2189         Germany                       Internet Database Specialist   36
# 2187         Germany                       Internet Database Specialist   28
# 2186         Germany                       Internet Database Specialist   24
# 2185         Germany                       Internet Database Specialist   19
# 2184         Germany                                Health Data Analyst   31
# 2183         Germany    Head of Information Systems and Data Processing   50
# 2182         Germany    Head of Information Systems and Data Processing   48
# 2180         Germany    Head of Information Systems and Data Processing   45
# 2166         Germany  Geographic Information Systems Database Admini...   19
# 2178         Germany    Head of Information Systems and Data Processing   34
# 2177         Germany    Head of Information Systems and Data Processing   33
# 2175         Germany    Head of Information Systems and Data Processing   23
# 2174         Germany    Head of Information Systems and Data Processing   22
# 2172         Germany  Geographic Information Systems Database Admini...   44
# 2170         Germany  Geographic Information Systems Database Admini...   34
# 2169         Germany  Geographic Information Systems Database Admini...   30
# 2167         Germany  Geographic Information Systems Database Admini...   26
# 6140  United Kingdom                             Survey Data Technician   38
#
#       Quantity Percentage
# 6101        27      0.28%
# 2218        27      0.28%
# 2216        26      0.27%
# 2217        26      0.27%
# 1464        25      0.26%
# 1444        25      0.26%
# 2215        25      0.26%
# 5322        25      0.26%
# 6073        24      0.25%
# 2214        23      0.24%
# 2219        22      0.23%
# 1442        22      0.23%
# 5300        22      0.23%
# 2224        22      0.23%
# 3307        21      0.22%
# 3313        20      0.21%
# 3323        20      0.21%
# 2239        20      0.21%
# 1443        19       0.2%
# 6074        19       0.2%
# 6077        19       0.2%
# 6076        18      0.19%
# 6098        18      0.19%
# 6099        18      0.19%
# 4157        18      0.19%
# 4156        18      0.19%
# 5321        18      0.19%
# 3304        18      0.19%
# 6075        17      0.18%
# 1449        17      0.18%
# ...        ...        ...
# 2150         1      0.01%
# 2149         1      0.01%
# 2146         1      0.01%
# 2145         1      0.01%
# 2144         1      0.01%
# 2143         1      0.01%
# 2142         1      0.01%
# 2163         1      0.01%
# 2165         1      0.01%
# 2191         1      0.01%
# 2181         1      0.01%
# 2190         1      0.01%
# 2189         1      0.01%
# 2187         1      0.01%
# 2186         1      0.01%
# 2185         1      0.01%
# 2184         1      0.01%
# 2183         1      0.01%
# 2182         1      0.01%
# 2180         1      0.01%
# 2166         1      0.01%
# 2178         1      0.01%
# 2177         1      0.01%
# 2175         1      0.01%
# 2174         1      0.01%
# 2172         1      0.01%
# 2170         1      0.01%
# 2169         1      0.01%
# 2167         1      0.01%
# 6140         1      0.01%
#
# [6141 rows x 5 columns]

# %%
list_count = ['Spain','Germany']
df_filter = df['Country'].isin(list_count)
df[df_filter]
# Out:
#       Country                                          Job Title  Age  \
# 2218  Germany                                   No Full-Time Job   19
# 2216  Germany                                   No Full-Time Job   17
# 2217  Germany                                   No Full-Time Job   18
# 2215  Germany                                   No Full-Time Job   16
# 5322    Spain                                   No Full-Time Job   41
# 2214  Germany                                   No Full-Time Job   15
# 2219  Germany                                   No Full-Time Job   20
# 5300    Spain                                   No Full-Time Job   19
# 2224  Germany                                   No Full-Time Job   25
# 2239  Germany                                   No Full-Time Job   40
# 5321    Spain                                   No Full-Time Job   40
# 5325    Spain                                   No Full-Time Job   44
# 5324    Spain                                   No Full-Time Job   43
# 5299    Spain                                   No Full-Time Job   18
# 2240  Germany                                   No Full-Time Job   41
# 2232  Germany                                   No Full-Time Job   33
# 2225  Germany                                   No Full-Time Job   26
# 2244  Germany                                   No Full-Time Job   45
# 2230  Germany                                   No Full-Time Job   31

# %%
import pandas as pd

# %%
path='../data/processed/01_FULL_raw_table.csv'
raw_df = pd.read_csv(path)


def make_final_base_table(raw_df, country):
    # creamos un nuevo df con las columnas necesarias más una
    df = raw_df[['country', 'title', 'age', 'gender']]

    df = df.rename(columns={'country': 'Country',
                            'title': 'Job Title',
                            'age': 'Age',
                            'gender': 'Quantity'
                            })
    
    # se añade una columna sobre gender con la cuenta de pais, job, tabajo
    df = df.groupby(['Country', 'Job Title', 'Age']).agg('count').reset_index()

    # Si no se mete valor, devuelve el df tal cual.
    if country == 'all':
        df['Percentage'] = df['Quantity'] / df['Country'].count() * 100
        df = df.sort_values(by=['Percentage'], ascending=False)
        return df

    # Si se mete valor, hace un filtro y recalcula el porcentaje.
    else:
        filter_country = df['Country'] == country
        df = df[filter_country]
        df['Percentage'] = df['Quantity'] / df['Country'].count() * 100
        df = df.sort_values(by=['Percentage'], ascending=False)
        return df


def pretty_df_percentage(df):
    df['Percentage'] = df['Percentage'].round(2).apply(lambda x : str(x)+'%')
    return df

def main_table_ch1 (raw_df,pais='all'):
    table = make_final_base_table(raw_df,pais)
    final_table = pretty_df_percentage(table)

    FILES_BASE_PATH = '../data/results/'
    name = FILES_BASE_PATH + 'challenge1.csv'
    final_table.to_csv(name, index=False)

    return final_table

# %%
main_table_ch1(raw_df,'France')
# Out:
#      Country                                Job Title  Age  Quantity  \
# 1464  France                         No Full-Time Job   40        25
# 1444  France                         No Full-Time Job   20        25
# 1442  France                         No Full-Time Job   18        22
# 1443  France                         No Full-Time Job   19        19
# 1449  France                         No Full-Time Job   25        17
# 1467  France                         No Full-Time Job   43        16
# 1469  France                         No Full-Time Job   45        16
# 1465  France                         No Full-Time Job   41        15
# 1445  France                         No Full-Time Job   21        15
# 1453  France                         No Full-Time Job   29        14
# 1447  France                         No Full-Time Job   23        13
# 1452  France                         No Full-Time Job   28        13
# 1479  France                         No Full-Time Job   55        13
# 1456  France                         No Full-Time Job   32        12
# 1446  France                         No Full-Time Job   22        12
# 1441  France                         No Full-Time Job   17        12
# 1440  France                         No Full-Time Job   16        12
# 1474  France                         No Full-Time Job   50        12
# 1460  France                         No Full-Time Job   36        12
# 1483  France                         No Full-Time Job   59        11
# 1439  France                         No Full-Time Job   15        11
# 1470  France                         No Full-Time Job   46        11
# 1451  France                         No Full-Time Job   27        11
# 1450  France                         No Full-Time Job   26        11
# 1476  France                         No Full-Time Job   52        10
# 1471  France                         No Full-Time Job   47        10
# 1468  France                         No Full-Time Job   44        10
# 1461  France                         No Full-Time Job   37        10
# 1472  France                         No Full-Time Job   48        10
# 1473  France                         No Full-Time Job   49         9
